# %%
from hanlp.utils.torch_util import gpus_available
import hanlp
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %% [markdown]
# 调用`hanlp.load`进行加载，模型会自动下载到本地缓存。

# %%
HanLP = hanlp.load(hanlp.pretrained.mtl.CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_BASE_ZH)

# %%
HanLP('阿婆主来到北京立方庭参观自然语义科技公司。', tasks='tok/coarse').pretty_print()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 HanLP('阿婆主来到北京立方庭参观自然语义科技公司。', tasks='tok/coarse').pretty_print()       │
# │   2                                                                                              │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\components\mtl\multi_task_learning.py │
# │ :773 in __call__                                                                                 │
# │                                                                                                  │
# │   770 │   │   raise NotImplementedError('Parallelization is not implemented yet.')               │
# │   771 │                                                                                          │
# │   772 │   def __call__(self, data, **kwargs) -> Document:                                        │
# │ ❱ 773 │   │   return super().__call__(data, **kwargs)                                            │
# │   774 │                                                                                          │
# │   775 │   def __getitem__(self, task_name: str) -> Task:                                         │
# │   776 │   │   return self.tasks[task_name]                                                       │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\utils\_contextlib.py:115 in           │
# │ decorate_context                                                                                 │
# │                                                                                                  │
# │   112 │   @functools.wraps(func)                                                                 │
# │   113 │   def decorate_context(*args, **kwargs):                                                 │
# │   114 │   │   with ctx_factory():                                                                │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                   │
# │   116 │                                                                                          │
# │   117 │   return decorate_context                                                                │
# │   118                                                                                            │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\common\torch_component.py:638 in      │
# │ __call__                                                                                         │
# │                                                                                                  │
# │   635 │   │   │   *args: Sentences or tokens.                                                    │
# │   636 │   │   │   **kwargs: Used in sub-classes.                                                 │
# │   637 │   │   """                                                                                │
# │ ❱ 638 │   │   return super().__call__(*args, **merge_dict(self.config, overwrite=True, **kwarg   │
# │   639                                                                                            │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\common\component.py:36 in __call__    │
# │                                                                                                  │
# │   33 │   │   Returns: Any predicted annotations.                                                 │
# │   34 │   │                                                                                       │
# │   35 │   │   """                                                                                 │
# │ ❱ 36 │   │   return self.predict(*args, **kwargs)                                                │
# │   37                                                                                             │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\components\mtl\multi_task_learning.py │
# │ :506 in predict                                                                                  │
# │                                                                                                  │
# │   503 │   │   for batch in dataloader:                                                           │
# │   504 │   │   │   order.extend(batch[IDX])                                                       │
# │   505 │   │   │   # Run the first task, let it make the initial batch for the successors         │
# │ ❱ 506 │   │   │   output_dict = self.predict_task(first_task, first_task_name, batch, results,   │
# │   507 │   │   │   │   │   │   │   │   │   │   │   cls_is_bos=cls_is_bos, sep_is_eos=sep_is_eos   │
# │   508 │   │   │   # Run each task group in order                                                 │
# │   509 │   │   │   for group_id, group in enumerate(target_tasks):                                │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\components\mtl\multi_task_learning.py │
# │ :595 in predict_task                                                                             │
# │                                                                                                  │
# │   592 │                                                                                          │
# │   593 │   def predict_task(self, task: Task, output_key, batch, results, output_dict=None, run   │
# │   594 │   │   │   │   │    cls_is_bos=True, sep_is_eos=True):                                    │
# │ ❱ 595 │   │   output_dict, batch = self.feed_batch(batch, output_key, output_dict, run_transfo   │
# │   596 │   │   │   │   │   │   │   │   │   │   │    results)                                      │
# │   597 │   │   self.decode_output(output_dict, batch, output_key)                                 │
# │   598 │   │   results[output_key].extend(task.prediction_to_result(output_dict[output_key]['pr   │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\components\mtl\multi_task_learning.py │
# │ :681 in feed_batch                                                                               │
# │                                                                                                  │
# │   678 │   │   │   │      cls_is_bos=False,                                                       │
# │   679 │   │   │   │      sep_is_eos=False,                                                       │
# │   680 │   │   │   │      results=None) -> Tuple[Dict[str, Any], Dict[str, Any]]:                 │
# │ ❱ 681 │   │   h, output_dict = self._encode(batch, task_name, output_dict, cls_is_bos, sep_is_   │
# │   682 │   │   task = self.tasks[task_name]                                                       │
# │   683 │   │   if run_transform:                                                                  │
# │   684 │   │   │   batch = task.transform_batch(batch, results=results, cls_is_bos=cls_is_bos,    │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\components\mtl\multi_task_learning.py │
# │ :700 in _encode                                                                                  │
# │                                                                                                  │
# │   697 │   │   if output_dict:                                                                    │
# │   698 │   │   │   hidden, raw_hidden = output_dict['hidden'], output_dict['raw_hidden']          │
# │   699 │   │   else:                                                                              │
# │ ❱ 700 │   │   │   hidden = model.encoder(batch)                                                  │
# │   701 │   │   │   if isinstance(hidden, tuple):                                                  │
# │   702 │   │   │   │   hidden, raw_hidden = hidden                                                │
# │   703 │   │   │   else:                                                                          │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\layers\embeddings\contextual_word_emb │
# │ edding.py:62 in forward                                                                          │
# │                                                                                                  │
# │    59 │   │   #     input_ids = input_ids.to(this_device)                                        │
# │    60 │   │   #     token_span = token_span.to(this_device)                                      │
# │    61 │   │   # We might want to apply mask here                                                 │
# │ ❱  62 │   │   output: Union[torch.Tensor, List[torch.Tensor]] = super().forward(input_ids, tok   │
# │    63 │   │   # if input_device != this_device:                                                  │
# │    64 │   │   #     if isinstance(output, torch.Tensor):                                         │
# │    65 │   │   #         output = output.to(input_device)                                         │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\layers\transformers\encoder.py:101 in │
# │ forward                                                                                          │
# │                                                                                                  │
# │    98 │   │   if self.word_dropout:                                                              │
# │    99 │   │   │   input_ids = self.word_dropout(input_ids)                                       │
# │   100 │   │                                                                                      │
# │ ❱ 101 │   │   x = transformer_encode(self.transformer,                                           │
# │   102 │   │   │   │   │   │   │      input_ids,                                                  │
# │   103 │   │   │   │   │   │   │      attention_mask,                                             │
# │   104 │   │   │   │   │   │   │      token_type_ids,                                             │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\hanlp\layers\transformers\utils.py:51 in    │
# │ transformer_encode                                                                               │
# │                                                                                                  │
# │    48 │   │   if transformer.config.output_hidden_states:                                        │
# │    49 │   │   │   outputs = transformer(input_ids, attention_mask, token_type_ids)[-1]           │
# │    50 │   │   else:                                                                              │
# │ ❱  51 │   │   │   outputs = transformer(input_ids, attention_mask, token_type_ids)[0]            │
# │    52 │   if transformer.config.output_hidden_states:                                            │
# │    53 │   │   if isinstance(layer_range, int):                                                   │
# │    54 │   │   │   outputs = outputs[layer_range:]                                                │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\Administrator\AppData\Roaming\Python\Python310\site-packages\transformers\models\electr │
# │ a\modeling_electra.py:919 in forward                                                             │
# │                                                                                                  │
# │    916 │   │   if hasattr(self, "embeddings_project"):                                           │
# │    917 │   │   │   hidden_states = self.embeddings_project(hidden_states)                        │
# │    918 │   │                                                                                     │
# │ ❱  919 │   │   hidden_states = self.encoder(                                                     │
# │    920 │   │   │   hidden_states,                                                                │
# │    921 │   │   │   attention_mask=extended_attention_mask,                                       │
# │    922 │   │   │   head_mask=head_mask,                                                          │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\Administrator\AppData\Roaming\Python\Python310\site-packages\transformers\models\electr │
# │ a\modeling_electra.py:588 in forward                                                             │
# │                                                                                                  │
# │    585 │   │   │   │   │   encoder_attention_mask,                                               │
# │    586 │   │   │   │   )                                                                         │
# │    587 │   │   │   else:                                                                         │
# │ ❱  588 │   │   │   │   layer_outputs = layer_module(                                             │
# │    589 │   │   │   │   │   hidden_states,                                                        │
# │    590 │   │   │   │   │   attention_mask,                                                       │
# │    591 │   │   │   │   │   layer_head_mask,                                                      │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\Administrator\AppData\Roaming\Python\Python310\site-packages\transformers\models\electr │
# │ a\modeling_electra.py:472 in forward                                                             │
# │                                                                                                  │
# │    469 │   ) -> Tuple[torch.Tensor]:                                                             │
# │    470 │   │   # decoder uni-directional self-attention cached key/values tuple is at positions  │
# │    471 │   │   self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else  │
# │ ❱  472 │   │   self_attention_outputs = self.attention(                                          │
# │    473 │   │   │   hidden_states,                                                                │
# │    474 │   │   │   attention_mask,                                                               │
# │    475 │   │   │   head_mask,                                                                    │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\Administrator\AppData\Roaming\Python\Python310\site-packages\transformers\models\electr │
# │ a\modeling_electra.py:399 in forward                                                             │
# │                                                                                                  │
# │    396 │   │   past_key_value: Optional[Tuple[Tuple[torch.FloatTensor]]] = None,                 │
# │    397 │   │   output_attentions: Optional[bool] = False,                                        │
# │    398 │   ) -> Tuple[torch.Tensor]:                                                             │
# │ ❱  399 │   │   self_outputs = self.self(                                                         │
# │    400 │   │   │   hidden_states,                                                                │
# │    401 │   │   │   attention_mask,                                                               │
# │    402 │   │   │   head_mask,                                                                    │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ C:\Users\Administrator\AppData\Roaming\Python\Python310\site-packages\transformers\models\electr │
# │ a\modeling_electra.py:256 in forward                                                             │
# │                                                                                                  │
# │    253 │   │   past_key_value: Optional[Tuple[Tuple[torch.FloatTensor]]] = None,                 │
# │    254 │   │   output_attentions: Optional[bool] = False,                                        │
# │    255 │   ) -> Tuple[torch.Tensor]:                                                             │
# │ ❱  256 │   │   mixed_query_layer = self.query(hidden_states)                                     │
# │    257 │   │                                                                                     │
# │    258 │   │   # If this is instantiated as a cross-attention module, the keys                   │
# │    259 │   │   # and values come from an encoder; the attention mask needs to be                 │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1502 in          │
# │ _wrapped_call_impl                                                                               │
# │                                                                                                  │
# │   1499 │   │   if self._compiled_call_impl is not None:                                          │
# │   1500 │   │   │   return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]        │
# │   1501 │   │   else:                                                                             │
# │ ❱ 1502 │   │   │   return self._call_impl(*args, **kwargs)                                       │
# │   1503 │                                                                                         │
# │   1504 │   def _call_impl(self, *args, **kwargs):                                                │
# │   1505 │   │   forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.fo  │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\module.py:1511 in          │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1508 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1509 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1510 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1511 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1512 │   │   # Do not call functions when jit is used                                          │
# │   1513 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1514 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ c:\ProgramData\anaconda3\envs\py10\lib\site-packages\torch\nn\modules\linear.py:114 in forward   │
# │                                                                                                  │
# │   111 │   │   │   init.uniform_(self.bias, -bound, bound)                                        │
# │   112 │                                                                                          │
# │   113 │   def forward(self, input: Tensor) -> Tensor:                                            │
# │ ❱ 114 │   │   return F.linear(input, self.weight, self.bias)                                     │
# │   115 │                                                                                          │
# │   116 │   def extra_repr(self) -> str:                                                           │
# │   117 │   │   return 'in_features={}, out_features={}, bias={}'.format(                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: CUDA error: CUBLAS_STATUS_NOT_INITIALIZED when calling `cublasCreate(handle)`
